# %%
pip install fredapi alpha_vantage yfinance matplotlib pandas plotly plotly_express plotly_geo mplfinance prophet pytrends pytrends

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY_1')

# %%
from google.colab import userdata
userdata.get('ALPHA_VANTAGE_API')

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')

# %%
from google.colab import userdata
userdata.get('FRED_API_KEY')

# %% [markdown]
# # Task
# Combine the provided lists of FRED series codes and descriptions with 100 additional popular FRED indicators and display the complete list.

# %% [markdown]
# ## Combine provided lists
#
# ### Subtask:
# Combine the two provided lists of FRED series codes and descriptions into a single list.
