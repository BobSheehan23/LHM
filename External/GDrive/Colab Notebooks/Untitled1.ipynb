# %%
import pandas as pd

holdings_df = pd.read_csv('/R3K_Holdings.csv')
display(holdings_df.head())

# %% [markdown]
# To effectively use the Orbisa API, I need more details on its structure and how to make specific data requests. This includes understanding:
#
# *   The exact endpoints for short sale and financing data.
# *   How to authenticate requests.
# *   The required parameters for filtering by ticker and date.
# *   The format of the data returned by the API.
#
# Once I have this information, I can write the code to retrieve the data for your holdings.

# %%
# Execute find_orbisa_key.py to locate the Orbisa key
# %run /find_orbisa_key.py

# %%
# Execute get_fresh_token.py to obtain a new JWT token
# %run /get_fresh_token.py

# %%
# Execute check_jwt_token.py to validate the obtained JWT token
# %run /check_jwt_token.py

# %%
import json

jwt_token = "eyJhbGciOiJIUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICI2NDQ3OTUyNS1kMWY2LTRjMTItOGYwZS1mMzY3ZjJiMzRkODMifQ.....3mQ4nEkNkKZiiaf05uj1gBTddZmkEDnvL96FrMXBzbE"

config = {"jwt_token": jwt_token}

with open('orbisa_config.json', 'w') as f:
    json.dump(config, f)

print("JWT token saved to orbisa_config.json")

# %%
# Execute find_orbisa_key.py to locate the Orbisa key
# %run /find_orbisa_key.py

# %%
# Execute get_fresh_token.py to obtain a new JWT token
# %run /get_fresh_token.py
