# %%
# Loaded variable 'df' from URI: /Users/bob/LHM/scripts/HORIZON_2026_PACKAGE/HORIZON_DATA_EXPORT.xlsx
import pandas as pd
df = pd.read_excel(r'/Users/bob/LHM/scripts/HORIZON_2026_PACKAGE/HORIZON_DATA_EXPORT.xlsx')
